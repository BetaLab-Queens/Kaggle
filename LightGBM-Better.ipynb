# %%
import numpy as np 
import pandas as pd

from lightgbm import LGBMClassifier,cv, Dataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
import string
from category_encoders import TargetEncoder

# %%
df_train = pd.read_csv("train.csv",index_col=0)
df_test = pd.read_csv("test.csv",index_col=0)

# %%
ord_1_map  = dict(Novice=0,Contributor=1,Expert=2,Master=3,Grandmaster=4)
ord_2_map = dict(Freezing=0,Cold=1,Warm=2,Hot=3)
ord_2_map.update({'Boiling Hot':4,'Lava Hot':5})
ord_3_lookup = {j:i for (i,j) in zip(range(len(string.ascii_lowercase)),string.ascii_lowercase)}
ord_4_lookup = {j:i for (i,j) in zip(range(len(string.ascii_lowercase)),string.ascii_uppercase)}

df_train.ord_1 = df_train.ord_1.map(ord_1_map)
df_train.ord_2 = df_train.ord_2.map(ord_2_map)
df_train.ord_3 = df_train.ord_3.map(ord_3_lookup)
df_train.ord_4 = df_train.ord_4.map(ord_4_lookup)

df_test.ord_1 = df_test.ord_1.map(ord_1_map)
df_test.ord_2 = df_test.ord_2.map(ord_2_map)
df_test.ord_3 = df_test.ord_3.map(ord_3_lookup)
df_test.ord_4 = df_test.ord_4.map(ord_4_lookup)
ords = ['ord_1','ord_2','ord_3','ord_4']
df_train[ords] = df_train[ords].astype("O")
df_test[ords] = df_test[ords].astype("O")

# %%
len(df_train.columns)
# Out:
# 24

# %%
len(df_test.columns)
# Out:
# 23

# %%
X = df_train.drop(["target"],axis=1)
y = df_train.target
for col in X.select_dtypes("O"):
    X[col] = X[col].astype('category')

nom_cols = [f'nom_{i}' for i in range(4,10)]   
enc = TargetEncoder(cols=nom_cols).fit(X, y)
df_train = enc.transform(X)
df_test = enc.transform(df_test)

X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.7)

# %%
params = {'learning_rate': 0.05,
          'metric': 'auc',
          'n_jobs': -1,
          'n_estimators' : 1000,
          'feature_fraction_seed': 0,
          'bagging_seed': 0,
          'boosting_type': 'gbdt',
          'verbose': 1,
          'is_unbalance': True}
estimated_params = {'colsample_bytree': 0.6377497065362651, 'min_child_samples': 323, 'min_child_weight': 0.1, 'num_leaves': 10, 'reg_alpha': 100, 'reg_lambda': 0.1, 'subsample': 0.9071147321063562}
model = LGBMClassifier(**params,**estimated_params)

# %%
# %%time
model.fit(X_train,y_train,eval_metric='AUC',eval_set = [(X_test, y_test)],
                  verbose = 1000,
                  early_stopping_rounds = 1000)
# Out:
# Training until validation scores don't improve for 1000 rounds
# [1000]	valid_0's auc: 0.793794
# Did not meet early stopping. Best iteration is:
# [600]	valid_0's auc: 0.794302
# CPU times: user 3min 28s, sys: 431 ms, total: 3min 29s
# Wall time: 29.9 s
# LGBMClassifier(bagging_seed=0, boosting_type='gbdt', class_weight=None,
#                colsample_bytree=0.6377497065362651, feature_fraction_seed=0,
#                importance_type='split', is_unbalance=True, learning_rate=0.05,
#                max_depth=-1, metric='auc', min_child_samples=323,
#                min_child_weight=0.1, min_split_gain=0.0, n_estimators=1000,
#                n_jobs=-1, num_leaves=10, objective=None, random_state=None,
#                reg_alpha=100, reg_lambda=0.1, silent=True,
#                subsample=0.9071147321063562, subsample_for_bin=200000,
#                subsample_freq=0, verbose=1)

# %%
# X = Dataset(X_train,y_train)
# X_eval = Dataset(X_test, y_test)

# %%
# cv(params,train_set=X,metrics='AUC',early_stopping_rounds = 1000)

# %%
preds = model.predict_proba(X_test)
roc_auc_score(y_test, preds[:, 1])
# Out:
# 0.7943018217067366

# %% [markdown]
# # Define Random Grid Search

# %%
# https://www.kaggle.com/mlisovyi/lightgbm-hyperparameter-optimisation-lb-0-761

# %%
# from scipy.stats import randint as sp_randint
# from scipy.stats import uniform as sp_uniform
# param_test ={'num_leaves': sp_randint(6, 50), 
#              'min_child_samples': sp_randint(100, 500), 
#              'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
#              'subsample': sp_uniform(loc=0.2, scale=0.8), 
#              'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
#              'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
#              'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

# %%
# fit_params={"early_stopping_rounds":30, 
#             "eval_metric" : 'auc', 
#             "eval_set" : [(X_test,y_test)],
#             'eval_names': ['valid'],
#             #'callbacks': [lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_099)],
#             'verbose': 100,
#             'categorical_feature': 'auto',
#            'is_unbalance':True}

# %%
# n_HP_points_to_test = 100

# import lightgbm as lgb
# from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# #n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
# clf = lgb.LGBMClassifier(max_depth=-1, random_state=0, silent=True, metric='None', n_jobs=4, n_estimators=5000)
# gs = RandomizedSearchCV(
#     estimator=clf, param_distributions=param_test, 
#     n_iter=n_HP_points_to_test,
#     scoring='roc_auc',
#     cv=3,
#     refit=True,
#     random_state=314,
#     verbose=True)

# %%
# %%time
# gs.fit(X_train,y_train,**fit_params)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767017
# Early stopping, best iteration is:
# [88]	valid's auc: 0.767147
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76791
# Early stopping, best iteration is:
# [101]	valid's auc: 0.767951
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767614
# Early stopping, best iteration is:
# [105]	valid's auc: 0.767696
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.765044
# Early stopping, best iteration is:
# [83]	valid's auc: 0.765439
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767362
# Early stopping, best iteration is:
# [105]	valid's auc: 0.767514
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.766355
# Early stopping, best iteration is:
# [91]	valid's auc: 0.766469
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726104
# [200]	valid's auc: 0.732117
# [300]	valid's auc: 0.733579
# [400]	valid's auc: 0.734333
# [500]	valid's auc: 0.734736
# [600]	valid's auc: 0.734935
# [700]	valid's auc: 0.735094
# [800]	valid's auc: 0.735175
# [900]	valid's auc: 0.735246
# [1000]	valid's auc: 0.735302
# Early stopping, best iteration is:
# [987]	valid's auc: 0.73531
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726479
# [200]	valid's auc: 0.732172
# [300]	valid's auc: 0.7338
# [400]	valid's auc: 0.734576
# [500]	valid's auc: 0.734973
# [600]	valid's auc: 0.735238
# [700]	valid's auc: 0.735401
# [800]	valid's auc: 0.735507
# [900]	valid's auc: 0.735565
# [1000]	valid's auc: 0.735617
# Early stopping, best iteration is:
# [1030]	valid's auc: 0.735643
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726707
# [200]	valid's auc: 0.73254
# [300]	valid's auc: 0.734088
# [400]	valid's auc: 0.734822
# [500]	valid's auc: 0.735167
# [600]	valid's auc: 0.735333
# [700]	valid's auc: 0.735464
# [800]	valid's auc: 0.735541
# Early stopping, best iteration is:
# [846]	valid's auc: 0.735575
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769144
# Early stopping, best iteration is:
# [110]	valid's auc: 0.769283
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770185
# Early stopping, best iteration is:
# [103]	valid's auc: 0.77027
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769904
# Early stopping, best iteration is:
# [99]	valid's auc: 0.769934
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.77222
# [200]	valid's auc: 0.774277
# Early stopping, best iteration is:
# [178]	valid's auc: 0.774493
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.773147
# [200]	valid's auc: 0.775638
# Early stopping, best iteration is:
# [190]	valid's auc: 0.775712
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771847
# [200]	valid's auc: 0.774151
# Early stopping, best iteration is:
# [196]	valid's auc: 0.774219
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76969
# Early stopping, best iteration is:
# [151]	valid's auc: 0.771388
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770197
# Early stopping, best iteration is:
# [163]	valid's auc: 0.771894
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769128
# Early stopping, best iteration is:
# [137]	valid's auc: 0.770825
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [65]	valid's auc: 0.757547
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [65]	valid's auc: 0.758733
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [63]	valid's auc: 0.758195
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.766139
# Early stopping, best iteration is:
# [104]	valid's auc: 0.766247
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.766705
# Early stopping, best iteration is:
# [105]	valid's auc: 0.76685
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.766522
# Early stopping, best iteration is:
# [104]	valid's auc: 0.766558
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768697
# Early stopping, best iteration is:
# [129]	valid's auc: 0.769364
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769607
# Early stopping, best iteration is:
# [116]	valid's auc: 0.770339
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769045
# Early stopping, best iteration is:
# [137]	valid's auc: 0.769805
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.765961
# Early stopping, best iteration is:
# [99]	valid's auc: 0.765983
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767583
# Early stopping, best iteration is:
# [98]	valid's auc: 0.76773
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.766737
# Early stopping, best iteration is:
# [99]	valid's auc: 0.766746
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.765741
# Early stopping, best iteration is:
# [104]	valid's auc: 0.765832
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.766184
# Early stopping, best iteration is:
# [98]	valid's auc: 0.766197
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76584
# Early stopping, best iteration is:
# [98]	valid's auc: 0.765862
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764482
# Early stopping, best iteration is:
# [96]	valid's auc: 0.764735
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.766268
# Early stopping, best iteration is:
# [96]	valid's auc: 0.766336
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764311
# Early stopping, best iteration is:
# [95]	valid's auc: 0.76451
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767218
# Early stopping, best iteration is:
# [97]	valid's auc: 0.76723
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76679
# Early stopping, best iteration is:
# [115]	valid's auc: 0.767003
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.766945
# Early stopping, best iteration is:
# [93]	valid's auc: 0.766989
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726702
# [200]	valid's auc: 0.732334
# [300]	valid's auc: 0.733864
# [400]	valid's auc: 0.734557
# [500]	valid's auc: 0.734898
# [600]	valid's auc: 0.735135
# [700]	valid's auc: 0.735268
# [800]	valid's auc: 0.735346
# [900]	valid's auc: 0.735419
# [1000]	valid's auc: 0.735464
# [1100]	valid's auc: 0.73549
# Early stopping, best iteration is:
# [1098]	valid's auc: 0.735493
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726118
# [200]	valid's auc: 0.731925
# [300]	valid's auc: 0.733565
# [400]	valid's auc: 0.734355
# [500]	valid's auc: 0.73483
# [600]	valid's auc: 0.735083
# [700]	valid's auc: 0.735241
# [800]	valid's auc: 0.735356
# Early stopping, best iteration is:
# [867]	valid's auc: 0.735393
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.727018
# [200]	valid's auc: 0.732378
# [300]	valid's auc: 0.73397
# [400]	valid's auc: 0.734724
# [500]	valid's auc: 0.735023
# [600]	valid's auc: 0.735222
# [700]	valid's auc: 0.735333
# [800]	valid's auc: 0.735408
# [900]	valid's auc: 0.735464
# [1000]	valid's auc: 0.735524
# [1100]	valid's auc: 0.735537
# Early stopping, best iteration is:
# [1082]	valid's auc: 0.735546
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769834
# [200]	valid's auc: 0.771898
# Early stopping, best iteration is:
# [182]	valid's auc: 0.771997
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770229
# [200]	valid's auc: 0.772534
# Early stopping, best iteration is:
# [181]	valid's auc: 0.772608
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770642
# [200]	valid's auc: 0.772759
# Early stopping, best iteration is:
# [212]	valid's auc: 0.772848
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767487
# Early stopping, best iteration is:
# [99]	valid's auc: 0.767546
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768808
# Early stopping, best iteration is:
# [99]	valid's auc: 0.768823
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767404
# Early stopping, best iteration is:
# [96]	valid's auc: 0.767428
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771201
# [200]	valid's auc: 0.773243
# Early stopping, best iteration is:
# [171]	valid's auc: 0.773397
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771659
# [200]	valid's auc: 0.77385
# Early stopping, best iteration is:
# [171]	valid's auc: 0.774034
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770907
# [200]	valid's auc: 0.773111
# Early stopping, best iteration is:
# [175]	valid's auc: 0.773491
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76879
# Early stopping, best iteration is:
# [119]	valid's auc: 0.769174
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769401
# Early stopping, best iteration is:
# [121]	valid's auc: 0.769951
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768802
# Early stopping, best iteration is:
# [118]	valid's auc: 0.768968
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770736
# Early stopping, best iteration is:
# [110]	valid's auc: 0.771173
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771296
# Early stopping, best iteration is:
# [129]	valid's auc: 0.771916
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770452
# Early stopping, best iteration is:
# [120]	valid's auc: 0.770598
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.756933
# Early stopping, best iteration is:
# [73]	valid's auc: 0.7582
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.758413
# Early stopping, best iteration is:
# [71]	valid's auc: 0.759687
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.757572
# Early stopping, best iteration is:
# [74]	valid's auc: 0.758493
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770882
# [200]	valid's auc: 0.77626
# [300]	valid's auc: 0.776872
# Early stopping, best iteration is:
# [331]	valid's auc: 0.777126
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771096
# [200]	valid's auc: 0.776737
# [300]	valid's auc: 0.777571
# Early stopping, best iteration is:
# [347]	valid's auc: 0.777735
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770621
# [200]	valid's auc: 0.77629
# [300]	valid's auc: 0.777041
# Early stopping, best iteration is:
# [292]	valid's auc: 0.777099
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769793
# Early stopping, best iteration is:
# [166]	valid's auc: 0.771443
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.77052
# Early stopping, best iteration is:
# [154]	valid's auc: 0.772268
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769926
# Early stopping, best iteration is:
# [150]	valid's auc: 0.77162
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.772277
# [200]	valid's auc: 0.77492
# Early stopping, best iteration is:
# [205]	valid's auc: 0.774949
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.772577
# [200]	valid's auc: 0.775801
# Early stopping, best iteration is:
# [212]	valid's auc: 0.775898
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771686
# [200]	valid's auc: 0.774911
# Early stopping, best iteration is:
# [219]	valid's auc: 0.775027
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771649
# [200]	valid's auc: 0.774713
# Early stopping, best iteration is:
# [209]	valid's auc: 0.774718
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771815
# [200]	valid's auc: 0.775207
# Early stopping, best iteration is:
# [247]	valid's auc: 0.775534
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770864
# [200]	valid's auc: 0.774068
# Early stopping, best iteration is:
# [250]	valid's auc: 0.774196
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.759114
# Early stopping, best iteration is:
# [74]	valid's auc: 0.76046
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.761004
# Early stopping, best iteration is:
# [70]	valid's auc: 0.762115
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.760264
# Early stopping, best iteration is:
# [75]	valid's auc: 0.761544
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726771
# [200]	valid's auc: 0.732446
# [300]	valid's auc: 0.733859
# [400]	valid's auc: 0.734564
# [500]	valid's auc: 0.734929
# [600]	valid's auc: 0.735128
# [700]	valid's auc: 0.735266
# [800]	valid's auc: 0.735371
# [900]	valid's auc: 0.735463
# Early stopping, best iteration is:
# [942]	valid's auc: 0.73549
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726253
# [200]	valid's auc: 0.732148
# [300]	valid's auc: 0.733692
# [400]	valid's auc: 0.734466
# [500]	valid's auc: 0.734892
# [600]	valid's auc: 0.735145
# [700]	valid's auc: 0.735301
# [800]	valid's auc: 0.735406
# [900]	valid's auc: 0.73547
# [1000]	valid's auc: 0.735506
# [1100]	valid's auc: 0.735557
# Early stopping, best iteration is:
# [1134]	valid's auc: 0.735578
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726765
# [200]	valid's auc: 0.732642
# [300]	valid's auc: 0.734139
# [400]	valid's auc: 0.734876
# [500]	valid's auc: 0.735218
# [600]	valid's auc: 0.735398
# [700]	valid's auc: 0.735539
# [800]	valid's auc: 0.735627
# [900]	valid's auc: 0.735707
# [1000]	valid's auc: 0.735739
# Early stopping, best iteration is:
# [1051]	valid's auc: 0.735759
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.765336
# Early stopping, best iteration is:
# [95]	valid's auc: 0.765495
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.766226
# Early stopping, best iteration is:
# [100]	valid's auc: 0.766226
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.765696
# Early stopping, best iteration is:
# [98]	valid's auc: 0.765823
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.763991
# Early stopping, best iteration is:
# [70]	valid's auc: 0.76422
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764891
# Early stopping, best iteration is:
# [86]	valid's auc: 0.765271
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.763827
# Early stopping, best iteration is:
# [96]	valid's auc: 0.764042
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771578
# [200]	valid's auc: 0.774604
# Early stopping, best iteration is:
# [175]	valid's auc: 0.774666
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771277
# [200]	valid's auc: 0.774979
# Early stopping, best iteration is:
# [230]	valid's auc: 0.775187
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771418
# Early stopping, best iteration is:
# [169]	valid's auc: 0.774561
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771861
# Early stopping, best iteration is:
# [131]	valid's auc: 0.772424
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.772589
# Early stopping, best iteration is:
# [149]	valid's auc: 0.773659
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.77162
# Early stopping, best iteration is:
# [119]	valid's auc: 0.772368
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.772058
# Early stopping, best iteration is:
# [150]	valid's auc: 0.773579
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.772636
# [200]	valid's auc: 0.77444
# Early stopping, best iteration is:
# [178]	valid's auc: 0.774717
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.772231
# Early stopping, best iteration is:
# [162]	valid's auc: 0.773913
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.763386
# Early stopping, best iteration is:
# [96]	valid's auc: 0.763811
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764264
# Early stopping, best iteration is:
# [98]	valid's auc: 0.764502
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76358
# Early stopping, best iteration is:
# [98]	valid's auc: 0.763732
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764072
# Early stopping, best iteration is:
# [84]	valid's auc: 0.764249
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.765184
# Early stopping, best iteration is:
# [89]	valid's auc: 0.765256
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764368
# Early stopping, best iteration is:
# [95]	valid's auc: 0.764501
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726415
# [200]	valid's auc: 0.732159
# [300]	valid's auc: 0.733614
# [400]	valid's auc: 0.734366
# [500]	valid's auc: 0.734751
# [600]	valid's auc: 0.734992
# [700]	valid's auc: 0.735136
# [800]	valid's auc: 0.735242
# [900]	valid's auc: 0.735299
# [1000]	valid's auc: 0.735366
# Early stopping, best iteration is:
# [1044]	valid's auc: 0.735381
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.72619
# [200]	valid's auc: 0.731924
# [300]	valid's auc: 0.733649
# [400]	valid's auc: 0.734388
# [500]	valid's auc: 0.734845
# [600]	valid's auc: 0.735099
# [700]	valid's auc: 0.735245
# [800]	valid's auc: 0.735336
# Early stopping, best iteration is:
# [828]	valid's auc: 0.735369
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.727206
# [200]	valid's auc: 0.732524
# [300]	valid's auc: 0.73405
# [400]	valid's auc: 0.734762
# [500]	valid's auc: 0.735123
# [600]	valid's auc: 0.735316
# [700]	valid's auc: 0.735439
# [800]	valid's auc: 0.73553
# [900]	valid's auc: 0.735586
# [1000]	valid's auc: 0.735617
# [1100]	valid's auc: 0.735664
# Early stopping, best iteration is:
# [1104]	valid's auc: 0.73567
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771464
# Early stopping, best iteration is:
# [125]	valid's auc: 0.772427
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.772057
# Early stopping, best iteration is:
# [131]	valid's auc: 0.773121
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771713
# Early stopping, best iteration is:
# [138]	valid's auc: 0.77258
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.765207
# Early stopping, best iteration is:
# [92]	valid's auc: 0.765585
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.766615
# Early stopping, best iteration is:
# [85]	valid's auc: 0.766845
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.765572
# Early stopping, best iteration is:
# [92]	valid's auc: 0.765832
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768683
# Early stopping, best iteration is:
# [99]	valid's auc: 0.768708
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768906
# Early stopping, best iteration is:
# [128]	valid's auc: 0.769194
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76861
# Early stopping, best iteration is:
# [98]	valid's auc: 0.768736
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726892
# [200]	valid's auc: 0.732563
# [300]	valid's auc: 0.733984
# [400]	valid's auc: 0.734672
# [500]	valid's auc: 0.735052
# [600]	valid's auc: 0.735255
# [700]	valid's auc: 0.735407
# [800]	valid's auc: 0.735468
# [900]	valid's auc: 0.735563
# [1000]	valid's auc: 0.735601
# [1100]	valid's auc: 0.735642
# Early stopping, best iteration is:
# [1153]	valid's auc: 0.735661
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726406
# [200]	valid's auc: 0.73221
# [300]	valid's auc: 0.733769
# [400]	valid's auc: 0.734534
# [500]	valid's auc: 0.734948
# [600]	valid's auc: 0.73521
# [700]	valid's auc: 0.735365
# [800]	valid's auc: 0.735458
# [900]	valid's auc: 0.735542
# [1000]	valid's auc: 0.735585
# Early stopping, best iteration is:
# [1012]	valid's auc: 0.735594
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.727262
# [200]	valid's auc: 0.732612
# [300]	valid's auc: 0.734142
# [400]	valid's auc: 0.73486
# [500]	valid's auc: 0.735208
# [600]	valid's auc: 0.735372
# [700]	valid's auc: 0.7355
# [800]	valid's auc: 0.735591
# [900]	valid's auc: 0.735669
# [1000]	valid's auc: 0.735722
# [1100]	valid's auc: 0.735742
# Early stopping, best iteration is:
# [1148]	valid's auc: 0.735775
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76798
# Early stopping, best iteration is:
# [100]	valid's auc: 0.76798
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769071
# Early stopping, best iteration is:
# [117]	valid's auc: 0.76926
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768817
# Early stopping, best iteration is:
# [103]	valid's auc: 0.768984
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.766042
# Early stopping, best iteration is:
# [100]	valid's auc: 0.766042
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767639
# Early stopping, best iteration is:
# [100]	valid's auc: 0.767639
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.765834
# Early stopping, best iteration is:
# [97]	valid's auc: 0.765858
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.761721
# Early stopping, best iteration is:
# [85]	valid's auc: 0.762335
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76293
# Early stopping, best iteration is:
# [74]	valid's auc: 0.763307
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.761806
# Early stopping, best iteration is:
# [85]	valid's auc: 0.762232
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726617
# [200]	valid's auc: 0.732447
# [300]	valid's auc: 0.733888
# [400]	valid's auc: 0.7346
# [500]	valid's auc: 0.734942
# [600]	valid's auc: 0.735176
# [700]	valid's auc: 0.735312
# [800]	valid's auc: 0.735409
# [900]	valid's auc: 0.735486
# [1000]	valid's auc: 0.735557
# [1100]	valid's auc: 0.735601
# [1200]	valid's auc: 0.735618
# Early stopping, best iteration is:
# [1266]	valid's auc: 0.735636
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726406
# [200]	valid's auc: 0.732181
# [300]	valid's auc: 0.73385
# [400]	valid's auc: 0.73457
# [500]	valid's auc: 0.734995
# [600]	valid's auc: 0.735223
# [700]	valid's auc: 0.735365
# [800]	valid's auc: 0.735482
# [900]	valid's auc: 0.735546
# [1000]	valid's auc: 0.735582
# [1100]	valid's auc: 0.735623
# [1200]	valid's auc: 0.735655
# Early stopping, best iteration is:
# [1256]	valid's auc: 0.735688
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726715
# [200]	valid's auc: 0.732536
# [300]	valid's auc: 0.734022
# [400]	valid's auc: 0.734737
# [500]	valid's auc: 0.735096
# [600]	valid's auc: 0.735296
# [700]	valid's auc: 0.735433
# [800]	valid's auc: 0.735519
# [900]	valid's auc: 0.735579
# [1000]	valid's auc: 0.735616
# [1100]	valid's auc: 0.735634
# Early stopping, best iteration is:
# [1083]	valid's auc: 0.73564
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771979
# [200]	valid's auc: 0.77548
# Early stopping, best iteration is:
# [215]	valid's auc: 0.775685
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.772549
# [200]	valid's auc: 0.77633
# Early stopping, best iteration is:
# [197]	valid's auc: 0.776399
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.772085
# [200]	valid's auc: 0.775465
# Early stopping, best iteration is:
# [228]	valid's auc: 0.77561
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [66]	valid's auc: 0.758485
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [68]	valid's auc: 0.760071
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.758107
# Early stopping, best iteration is:
# [76]	valid's auc: 0.759034
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768852
# Early stopping, best iteration is:
# [129]	valid's auc: 0.769787
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769868
# Early stopping, best iteration is:
# [129]	valid's auc: 0.770615
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769268
# Early stopping, best iteration is:
# [137]	valid's auc: 0.770222
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769129
# Early stopping, best iteration is:
# [119]	valid's auc: 0.769443
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769701
# Early stopping, best iteration is:
# [113]	valid's auc: 0.76993
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769895
# Early stopping, best iteration is:
# [114]	valid's auc: 0.770185
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770203
# Early stopping, best iteration is:
# [143]	valid's auc: 0.771131
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770454
# Early stopping, best iteration is:
# [143]	valid's auc: 0.771271
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770475
# Early stopping, best iteration is:
# [156]	valid's auc: 0.771406
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771826
# [200]	valid's auc: 0.774567
# Early stopping, best iteration is:
# [221]	valid's auc: 0.77461
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.77164
# [200]	valid's auc: 0.77519
# Early stopping, best iteration is:
# [213]	valid's auc: 0.775439
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771242
# [200]	valid's auc: 0.774195
# Early stopping, best iteration is:
# [219]	valid's auc: 0.774317
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [69]	valid's auc: 0.76102
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.762003
# Early stopping, best iteration is:
# [75]	valid's auc: 0.762462
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.760962
# Early stopping, best iteration is:
# [70]	valid's auc: 0.761243
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726701
# [200]	valid's auc: 0.732565
# [300]	valid's auc: 0.734015
# [400]	valid's auc: 0.734648
# [500]	valid's auc: 0.734995
# [600]	valid's auc: 0.735215
# [700]	valid's auc: 0.735342
# [800]	valid's auc: 0.735451
# [900]	valid's auc: 0.735525
# [1000]	valid's auc: 0.735574
# [1100]	valid's auc: 0.735631
# [1200]	valid's auc: 0.735664
# [1300]	valid's auc: 0.735699
# Early stopping, best iteration is:
# [1327]	valid's auc: 0.735704
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726254
# [200]	valid's auc: 0.732182
# [300]	valid's auc: 0.733744
# [400]	valid's auc: 0.734524
# [500]	valid's auc: 0.734943
# [600]	valid's auc: 0.735194
# [700]	valid's auc: 0.73534
# [800]	valid's auc: 0.735466
# [900]	valid's auc: 0.73554
# [1000]	valid's auc: 0.735593
# [1100]	valid's auc: 0.735624
# [1200]	valid's auc: 0.735666
# [1300]	valid's auc: 0.735692
# Early stopping, best iteration is:
# [1330]	valid's auc: 0.735706
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726854
# [200]	valid's auc: 0.732478
# [300]	valid's auc: 0.734127
# [400]	valid's auc: 0.734789
# [500]	valid's auc: 0.735145
# [600]	valid's auc: 0.735335
# [700]	valid's auc: 0.735481
# [800]	valid's auc: 0.735541
# [900]	valid's auc: 0.735611
# [1000]	valid's auc: 0.735673
# Early stopping, best iteration is:
# [1012]	valid's auc: 0.735683
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770165
# Early stopping, best iteration is:
# [145]	valid's auc: 0.770939
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771057
# Early stopping, best iteration is:
# [150]	valid's auc: 0.771396
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771135
# Early stopping, best iteration is:
# [143]	valid's auc: 0.771797
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764204
# Early stopping, best iteration is:
# [96]	valid's auc: 0.764367
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764263
# Early stopping, best iteration is:
# [78]	valid's auc: 0.764363
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.763895
# Early stopping, best iteration is:
# [99]	valid's auc: 0.763971
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771458
# Early stopping, best iteration is:
# [160]	valid's auc: 0.773531
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.77224
# [200]	valid's auc: 0.774506
# Early stopping, best iteration is:
# [207]	valid's auc: 0.774545
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770766
# [200]	valid's auc: 0.772912
# Early stopping, best iteration is:
# [184]	valid's auc: 0.772996
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764039
# Early stopping, best iteration is:
# [84]	valid's auc: 0.764368
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.765588
# Early stopping, best iteration is:
# [92]	valid's auc: 0.765948
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764195
# Early stopping, best iteration is:
# [80]	valid's auc: 0.764576
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769541
# Early stopping, best iteration is:
# [145]	valid's auc: 0.770725
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769685
# Early stopping, best iteration is:
# [167]	valid's auc: 0.771149
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770081
# Early stopping, best iteration is:
# [145]	valid's auc: 0.770989
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726134
# [200]	valid's auc: 0.732081
# [300]	valid's auc: 0.73371
# [400]	valid's auc: 0.734403
# [500]	valid's auc: 0.734829
# [600]	valid's auc: 0.735047
# [700]	valid's auc: 0.735186
# [800]	valid's auc: 0.735307
# [900]	valid's auc: 0.735377
# [1000]	valid's auc: 0.735422
# [1100]	valid's auc: 0.735459
# [1200]	valid's auc: 0.735473
# Early stopping, best iteration is:
# [1194]	valid's auc: 0.735479
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726231
# [200]	valid's auc: 0.732097
# [300]	valid's auc: 0.7337
# [400]	valid's auc: 0.734429
# [500]	valid's auc: 0.734847
# [600]	valid's auc: 0.735087
# [700]	valid's auc: 0.735239
# [800]	valid's auc: 0.735336
# [900]	valid's auc: 0.735383
# [1000]	valid's auc: 0.735431
# Early stopping, best iteration is:
# [1034]	valid's auc: 0.735469
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.727378
# [200]	valid's auc: 0.73272
# [300]	valid's auc: 0.734231
# [400]	valid's auc: 0.734917
# [500]	valid's auc: 0.735252
# [600]	valid's auc: 0.735444
# [700]	valid's auc: 0.735598
# [800]	valid's auc: 0.735659
# [900]	valid's auc: 0.735738
# [1000]	valid's auc: 0.735776
# Early stopping, best iteration is:
# [998]	valid's auc: 0.735778
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768825
# Early stopping, best iteration is:
# [115]	valid's auc: 0.769104
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770047
# Early stopping, best iteration is:
# [128]	valid's auc: 0.770178
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768938
# Early stopping, best iteration is:
# [111]	valid's auc: 0.769138
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770841
# Early stopping, best iteration is:
# [169]	valid's auc: 0.773437
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770912
# [200]	valid's auc: 0.773837
# Early stopping, best iteration is:
# [232]	valid's auc: 0.774233
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770801
# [200]	valid's auc: 0.773861
# Early stopping, best iteration is:
# [230]	valid's auc: 0.77392
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767593
# Early stopping, best iteration is:
# [104]	valid's auc: 0.767737
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767679
# Early stopping, best iteration is:
# [100]	valid's auc: 0.767679
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.766905
# Early stopping, best iteration is:
# [97]	valid's auc: 0.767025
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769581
# Early stopping, best iteration is:
# [96]	valid's auc: 0.769704
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770731
# Early stopping, best iteration is:
# [117]	valid's auc: 0.770864
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769491
# Early stopping, best iteration is:
# [104]	valid's auc: 0.769622
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [66]	valid's auc: 0.760426
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.760797
# Early stopping, best iteration is:
# [75]	valid's auc: 0.761604
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [67]	valid's auc: 0.760125
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771306
# Early stopping, best iteration is:
# [128]	valid's auc: 0.772201
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.772065
# Early stopping, best iteration is:
# [169]	valid's auc: 0.773329
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771539
# Early stopping, best iteration is:
# [138]	valid's auc: 0.77287
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [65]	valid's auc: 0.75756
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [67]	valid's auc: 0.757573
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.75499
# Early stopping, best iteration is:
# [73]	valid's auc: 0.756336
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769458
# Early stopping, best iteration is:
# [153]	valid's auc: 0.771038
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.7702
# Early stopping, best iteration is:
# [157]	valid's auc: 0.771795
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769628
# Early stopping, best iteration is:
# [161]	valid's auc: 0.770927
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76968
# [200]	valid's auc: 0.774524
# Early stopping, best iteration is:
# [230]	valid's auc: 0.775024
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769354
# [200]	valid's auc: 0.774801
# Early stopping, best iteration is:
# [233]	valid's auc: 0.775322
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769604
# [200]	valid's auc: 0.77448
# Early stopping, best iteration is:
# [237]	valid's auc: 0.774961
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.761109
# Early stopping, best iteration is:
# [71]	valid's auc: 0.762267
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.762753
# Early stopping, best iteration is:
# [78]	valid's auc: 0.763597
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76126
# Early stopping, best iteration is:
# [73]	valid's auc: 0.76215
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769991
# Early stopping, best iteration is:
# [119]	valid's auc: 0.770078
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770998
# Early stopping, best iteration is:
# [119]	valid's auc: 0.771251
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770047
# Early stopping, best iteration is:
# [111]	valid's auc: 0.770169
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.77019
# Early stopping, best iteration is:
# [153]	valid's auc: 0.77181
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770504
# Early stopping, best iteration is:
# [162]	valid's auc: 0.772664
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76937
# Early stopping, best iteration is:
# [154]	valid's auc: 0.772027
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768671
# Early stopping, best iteration is:
# [99]	valid's auc: 0.768749
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76953
# Early stopping, best iteration is:
# [111]	valid's auc: 0.76976
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769486
# Early stopping, best iteration is:
# [111]	valid's auc: 0.769572
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768682
# [200]	valid's auc: 0.774943
# [300]	valid's auc: 0.775836
# Early stopping, best iteration is:
# [279]	valid's auc: 0.775931
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768713
# [200]	valid's auc: 0.775366
# [300]	valid's auc: 0.776468
# Early stopping, best iteration is:
# [305]	valid's auc: 0.776547
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76885
# [200]	valid's auc: 0.774913
# [300]	valid's auc: 0.775781
# Early stopping, best iteration is:
# [304]	valid's auc: 0.775842
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768915
# [200]	valid's auc: 0.775429
# Early stopping, best iteration is:
# [250]	valid's auc: 0.775986
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769592
# [200]	valid's auc: 0.775447
# [300]	valid's auc: 0.776448
# Early stopping, best iteration is:
# [309]	valid's auc: 0.776585
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768606
# [200]	valid's auc: 0.774732
# Early stopping, best iteration is:
# [254]	valid's auc: 0.775551
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771803
# Early stopping, best iteration is:
# [124]	valid's auc: 0.772484
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.772261
# Early stopping, best iteration is:
# [130]	valid's auc: 0.773268
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771524
# Early stopping, best iteration is:
# [127]	valid's auc: 0.772357
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726774
# [200]	valid's auc: 0.732448
# [300]	valid's auc: 0.733853
# [400]	valid's auc: 0.734565
# [500]	valid's auc: 0.734972
# [600]	valid's auc: 0.735187
# [700]	valid's auc: 0.735338
# [800]	valid's auc: 0.735432
# [900]	valid's auc: 0.735507
# [1000]	valid's auc: 0.735546
# [1100]	valid's auc: 0.735577
# [1200]	valid's auc: 0.735632
# [1300]	valid's auc: 0.73565
# Early stopping, best iteration is:
# [1363]	valid's auc: 0.735681
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726256
# [200]	valid's auc: 0.732146
# [300]	valid's auc: 0.733754
# [400]	valid's auc: 0.734479
# [500]	valid's auc: 0.734932
# [600]	valid's auc: 0.735164
# [700]	valid's auc: 0.73533
# [800]	valid's auc: 0.735429
# [900]	valid's auc: 0.735492
# Early stopping, best iteration is:
# [877]	valid's auc: 0.735499
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.727053
# [200]	valid's auc: 0.732677
# [300]	valid's auc: 0.734212
# [400]	valid's auc: 0.734887
# [500]	valid's auc: 0.7352
# [600]	valid's auc: 0.735377
# [700]	valid's auc: 0.735493
# [800]	valid's auc: 0.73556
# Early stopping, best iteration is:
# [782]	valid's auc: 0.735571
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769713
# Early stopping, best iteration is:
# [147]	valid's auc: 0.770202
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770006
# Early stopping, best iteration is:
# [132]	valid's auc: 0.770604
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769945
# Early stopping, best iteration is:
# [143]	valid's auc: 0.770362
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770714
# Early stopping, best iteration is:
# [111]	valid's auc: 0.771082
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771923
# Early stopping, best iteration is:
# [131]	valid's auc: 0.772589
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770435
# Early stopping, best iteration is:
# [137]	valid's auc: 0.770814
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76955
# Early stopping, best iteration is:
# [116]	valid's auc: 0.770061
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.77025
# Early stopping, best iteration is:
# [126]	valid's auc: 0.770785
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769705
# Early stopping, best iteration is:
# [138]	valid's auc: 0.770379
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769409
# Early stopping, best iteration is:
# [157]	valid's auc: 0.770311
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769992
# [200]	valid's auc: 0.770883
# Early stopping, best iteration is:
# [182]	valid's auc: 0.771098
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770167
# Early stopping, best iteration is:
# [168]	valid's auc: 0.771162
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770592
# Early stopping, best iteration is:
# [117]	valid's auc: 0.770997
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.772276
# Early stopping, best iteration is:
# [127]	valid's auc: 0.773046
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.77099
# Early stopping, best iteration is:
# [125]	valid's auc: 0.771436
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.765563
# Early stopping, best iteration is:
# [88]	valid's auc: 0.765935
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767257
# Early stopping, best iteration is:
# [102]	valid's auc: 0.767342
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76536
# Early stopping, best iteration is:
# [85]	valid's auc: 0.765778
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767044
# Early stopping, best iteration is:
# [93]	valid's auc: 0.767548
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767265
# Early stopping, best iteration is:
# [110]	valid's auc: 0.767412
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76667
# Early stopping, best iteration is:
# [91]	valid's auc: 0.766789
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771779
# Early stopping, best iteration is:
# [142]	valid's auc: 0.773411
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.77211
# [200]	valid's auc: 0.773845
# Early stopping, best iteration is:
# [173]	valid's auc: 0.774043
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771523
# [200]	valid's auc: 0.773362
# Early stopping, best iteration is:
# [201]	valid's auc: 0.773417
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768732
# Early stopping, best iteration is:
# [104]	valid's auc: 0.768784
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769263
# Early stopping, best iteration is:
# [107]	valid's auc: 0.769398
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76942
# Early stopping, best iteration is:
# [127]	valid's auc: 0.769639
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.763308
# Early stopping, best iteration is:
# [80]	valid's auc: 0.763615
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764102
# Early stopping, best iteration is:
# [82]	valid's auc: 0.764591
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.762291
# Early stopping, best iteration is:
# [83]	valid's auc: 0.762746
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.758782
# Early stopping, best iteration is:
# [71]	valid's auc: 0.760146
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [66]	valid's auc: 0.760878
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [61]	valid's auc: 0.760285
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768997
# Early stopping, best iteration is:
# [112]	valid's auc: 0.769009
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768934
# Early stopping, best iteration is:
# [112]	valid's auc: 0.76935
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768348
# Early stopping, best iteration is:
# [117]	valid's auc: 0.768558
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769987
# Early stopping, best iteration is:
# [140]	valid's auc: 0.771117
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770051
# Early stopping, best iteration is:
# [163]	valid's auc: 0.771638
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769451
# Early stopping, best iteration is:
# [139]	valid's auc: 0.770879
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [68]	valid's auc: 0.759508
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [69]	valid's auc: 0.761763
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.759623
# Early stopping, best iteration is:
# [74]	valid's auc: 0.760267
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764386
# Early stopping, best iteration is:
# [98]	valid's auc: 0.764458
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764992
# Early stopping, best iteration is:
# [95]	valid's auc: 0.765204
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764032
# Early stopping, best iteration is:
# [96]	valid's auc: 0.764224
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.761965
# Early stopping, best iteration is:
# [70]	valid's auc: 0.762419
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.763471
# Early stopping, best iteration is:
# [92]	valid's auc: 0.763614
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.762386
# Early stopping, best iteration is:
# [96]	valid's auc: 0.762533
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768319
# Early stopping, best iteration is:
# [97]	valid's auc: 0.768466
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768896
# Early stopping, best iteration is:
# [116]	valid's auc: 0.769036
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768202
# Early stopping, best iteration is:
# [97]	valid's auc: 0.768272
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.765528
# Early stopping, best iteration is:
# [98]	valid's auc: 0.765748
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767193
# Early stopping, best iteration is:
# [97]	valid's auc: 0.767432
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.766128
# Early stopping, best iteration is:
# [96]	valid's auc: 0.766282
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.767979
# Early stopping, best iteration is:
# [98]	valid's auc: 0.768074
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768596
# Early stopping, best iteration is:
# [125]	valid's auc: 0.769057
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768602
# Early stopping, best iteration is:
# [106]	valid's auc: 0.768663
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770307
# Early stopping, best iteration is:
# [131]	valid's auc: 0.770805
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.77007
# Early stopping, best iteration is:
# [131]	valid's auc: 0.77123
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770445
# Early stopping, best iteration is:
# [130]	valid's auc: 0.771161
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769011
# Early stopping, best iteration is:
# [112]	valid's auc: 0.769297
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769926
# Early stopping, best iteration is:
# [124]	valid's auc: 0.770106
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768249
# Early stopping, best iteration is:
# [120]	valid's auc: 0.768477
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770876
# Early stopping, best iteration is:
# [161]	valid's auc: 0.773282
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.771438
# [200]	valid's auc: 0.774411
# Early stopping, best iteration is:
# [207]	valid's auc: 0.774566
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770555
# [200]	valid's auc: 0.773244
# Early stopping, best iteration is:
# [191]	valid's auc: 0.773353
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726262
# [200]	valid's auc: 0.731999
# [300]	valid's auc: 0.73358
# [400]	valid's auc: 0.734339
# [500]	valid's auc: 0.734753
# [600]	valid's auc: 0.734978
# [700]	valid's auc: 0.73514
# [800]	valid's auc: 0.735243
# [900]	valid's auc: 0.73533
# [1000]	valid's auc: 0.735382
# [1100]	valid's auc: 0.735432
# [1200]	valid's auc: 0.735466
# [1300]	valid's auc: 0.735495
# [1400]	valid's auc: 0.735516
# [1500]	valid's auc: 0.735536
# Early stopping, best iteration is:
# [1555]	valid's auc: 0.735552
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.725435
# [200]	valid's auc: 0.731849
# [300]	valid's auc: 0.733555
# [400]	valid's auc: 0.73427
# [500]	valid's auc: 0.734729
# [600]	valid's auc: 0.734965
# [700]	valid's auc: 0.735158
# [800]	valid's auc: 0.735273
# [900]	valid's auc: 0.735343
# [1000]	valid's auc: 0.735406
# [1100]	valid's auc: 0.735436
# Early stopping, best iteration is:
# [1110]	valid's auc: 0.735439
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.726859
# [200]	valid's auc: 0.732394
# [300]	valid's auc: 0.733993
# [400]	valid's auc: 0.734708
# [500]	valid's auc: 0.735058
# [600]	valid's auc: 0.735248
# [700]	valid's auc: 0.735369
# [800]	valid's auc: 0.735462
# [900]	valid's auc: 0.735544
# [1000]	valid's auc: 0.735594
# [1100]	valid's auc: 0.73564
# [1200]	valid's auc: 0.735681
# [1300]	valid's auc: 0.735695
# Early stopping, best iteration is:
# [1285]	valid's auc: 0.735697
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.76876
# Early stopping, best iteration is:
# [100]	valid's auc: 0.76876
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768083
# Early stopping, best iteration is:
# [119]	valid's auc: 0.768295
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768248
# Early stopping, best iteration is:
# [98]	valid's auc: 0.768282
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768718
# Early stopping, best iteration is:
# [118]	valid's auc: 0.769134
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769719
# Early stopping, best iteration is:
# [138]	valid's auc: 0.770198
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.768276
# Early stopping, best iteration is:
# [121]	valid's auc: 0.768903
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764281
# Early stopping, best iteration is:
# [87]	valid's auc: 0.764675
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.765547
# Early stopping, best iteration is:
# [97]	valid's auc: 0.765806
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.764549
# Early stopping, best iteration is:
# [97]	valid's auc: 0.764633
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769961
# Early stopping, best iteration is:
# [139]	valid's auc: 0.771306
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.770321
# Early stopping, best iteration is:
# [152]	valid's auc: 0.771541
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.769739
# Early stopping, best iteration is:
# [152]	valid's auc: 0.771158
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed: 43.4min finished
# Training until validation scores don't improve for 30 rounds
# [100]	valid's auc: 0.77272
# [200]	valid's auc: 0.778829
# [300]	valid's auc: 0.780034
# Early stopping, best iteration is:
# [316]	valid's auc: 0.780164
# CPU times: user 2h 40min 24s, sys: 36.1 s, total: 2h 41min
# Wall time: 43min 38s
# RandomizedSearchCV(cv=3, error_score=nan,
#                    estimator=LGBMClassifier(boosting_type='gbdt',
#                                             class_weight=None,
#                                             colsample_bytree=1.0,
#                                             importance_type='split',
#                                             learning_rate=0.1, max_depth=-1,
#                                             metric='None', min_child_samples=20,
#                                             min_child_weight=0.001,
#                                             min_split_gain=0.0,
#                                             n_estimators=5000, n_jobs=4,
#                                             num_leaves=31, objective=None,
#                                             random_state=0, reg_alpha=0.0,
#                                             reg_lamb...
#                                                              10000.0],
#                                         'num_leaves': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f0f9416da20>,
#                                         'reg_alpha': [0, 0.1, 1, 2, 5, 7, 10,
#                                                       50, 100],
#                                         'reg_lambda': [0, 0.1, 1, 5, 10, 20, 50,
#                                                        100],
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f0f9416d4e0>},
#                    pre_dispatch='2*n_jobs', random_state=314, refit=True,
#                    return_train_score=False, scoring='roc_auc', verbose=True)

# %%
# print('Best score reached: {} with params: {} '.format(gs.best_score_, gs.best_params_))
# with open("lightgbm.txt","w") as f:
#     f.write(f"{gs.best_params_}")
# Out:
# Best score reached: 0.7798876583558224 with params: {'colsample_bytree': 0.6377497065362651, 'min_child_samples': 323, 'min_child_weight': 0.1, 'num_leaves': 10, 'reg_alpha': 100, 'reg_lambda': 0.1, 'subsample': 0.9071147321063562}

# %%
for col in df_test.select_dtypes("O"):
    df_test[col] = df_test[col].astype("category")
sub = pd.read_csv("sample_submission.csv")
preds= model.predict_proba(df_test)
sub["target"] = preds[:, 1]
sub.head()
# Out:
#        id    target
# 0  600000  0.771439
# 1  600001  0.529288
# 2  600002  0.448376
# 3  600003  0.326631
# 4  600004  0.516396

# %%
sub.to_csv("preds/light.csv",index=False)
